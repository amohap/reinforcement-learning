# %%
import matplotlib.pyplot as plt
import pandas as pd
import os

# %%
epsilons=["0.10000", "0.20000", "0.90000"]
betas=["0.00005", "0.00050", "0.00500"]
gammas=["0.80000", "0.85000", "1.00000"]
etas=["0.00350", "0.00500", "0.05000"]

# %%
for epsilon in epsilons:
    for beta in betas:
        delta = pd.read_csv('ep%s_be%s_ga0.80000_et0.00350/Delta_save_QLearning.csv' %(epsilon,beta))
        delta['Delta_save'] = delta['Delta_save'].ewm(span=2000, adjust=False).mean()
        plt.plot(delta['Delta_save'], label='ep%s_be%s_ga0.80000_et0.00350' %(epsilon,beta))

plt.xlabel('Episodes')
plt.ylabel('Error')
plt.title('Average Loss')
plt.legend()
# plt.show()
plt.savefig('report_delta.png')
plt.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/sz/_h0l1zd56wl39cb0sdn2kw2w0000gn/T/ipykernel_90628/1536534213.py in <module>
#       1 for epsilon in epsilons:
#       2     for beta in betas:
# ----> 3         delta = pd.read_csv('ep%s_be%s_ga0.80000_et0.00350/Delta_save_QLearning.csv' %(epsilon,beta))
#       4         delta['Delta_save'] = delta['Delta_save'].ewm(span=2000, adjust=False).mean()
#       5         plt.plot(delta['Delta_save'], label='ep%s_be%s_ga0.80000_et0.00350' %(epsilon,beta))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
for epsilon in epsilons:
    for beta in betas:
        r = pd.read_csv('ep%s_be%s_ga0.80000_et0.00350/R_save_QLearning.csv' %(epsilon,beta))
        r['Delta_save'] = r['R_save'].ewm(span=2000, adjust=False).mean()
        plt.plot(r['R_save'], label='ep%s_be%s_ga0.80000_et0.00350' %(epsilon,beta))

plt.xlabel('Episodes')
plt.ylabel('Reward')
plt.title('Average Rewards per Episode')
plt.legend()
# plt.show()
plt.savefig('report_reward.png')
plt.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/sz/_h0l1zd56wl39cb0sdn2kw2w0000gn/T/ipykernel_90628/3132489291.py in <module>
#       1 for epsilon in epsilons:
#       2     for beta in betas:
# ----> 3         r = pd.read_csv('ep%s_be%s_ga0.80000_et0.00350/R_save_QLearning.csv' %(epsilon,beta))
#       4         r['Delta_save'] = r['R_save'].ewm(span=2000, adjust=False).mean()
#       5         plt.plot(r['R_save'], label='ep%s_be%s_ga0.80000_et0.00350' %(epsilon,beta))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...

# %%
for epsilon in epsilons:
    for beta in betas:
        m = pd.read_csv('ep%s_be%s_ga0.80000_et0.00350/N_moves_QLearning.csv' %(epsilon,beta))
        m['N_moves'] = m['N_moves'].ewm(span=2000, adjust=False).mean()
        plt.plot(m['N_moves'], label='ep%s_be%s_ga0.80000_et0.00350' %(epsilon,beta))

plt.xlabel('Episodes')
plt.ylabel('Number of Steps until "Done"')
plt.title('Average Number of Steps until "Done" per Episode')
plt.legend()
# plt.show()
plt.savefig('report_moves.png')
plt.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# /var/folders/sz/_h0l1zd56wl39cb0sdn2kw2w0000gn/T/ipykernel_90628/2534900567.py in <module>
#       1 for epsilon in epsilons:
#       2     for beta in betas:
# ----> 3         m = pd.read_csv('ep%s_be%s_ga0.80000_et0.00350/N_moves_QLearning.csv' %(epsilon,beta))
#       4         m['N_moves'] = m['N_moves'].ewm(span=2000, adjust=False).mean()
#       5         plt.plot(m['N_moves'], label='ep%s_be%s_ga0.80000_et0.00350' %(epsilon,beta))
#
# ~/opt/anaconda3/lib/python3.9/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ...
